# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91965\\Desktop\\PANDAS READ DATA\\PD'

# %%
os.chdir("C:\\Users\\91965\\Desktop\\PANDAS READ DATA\\PANDAS READ FILE WITH  DATA")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91965\\Desktop\\PANDAS READ DATA\\PANDAS READ FILE WITH  DATA'

# %%
os.listdir()[2]
# Out:
# 'article.txt'

# %%
# reading of excel data:

a=pd.read_excel("Sample - Superstore.xls")

# %%
a
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# to extract first 5 rows [but we can increase or decrease the no of extracted rows] 

a.head(4)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# ...

# %%
a["Customer Name"][2]
# Out:
# 'Darrin Van Huff'

# %%
# Information of data:

a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
a.drop(["Row ID","Postal Code"], axis=1).describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.shape
# Out:
# (9994, 21)

# %%
a.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
a.columns[4]
# Out:
# 'Ship Mode'

# %%
b=list(a)

# %%
b[2]
# Out:
# 'Order Date'

# %%
# empty data frame of the same columns

pd.DataFrame(columns=b)
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
# another way to creat blank data frame with the same columns:
x=pd.DataFrame(columns=a.columns)

# %%
x
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
# sorting of data on the basis of "Customer IDs" 

a.sort_values("Customer ID")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2229    2230  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 1160    1161  CA-2017-147039 2017-06-29 2017-07-04  Standard Class
# 2230    2231  CA-2014-128055 2014-03-31 2014-04-05  Standard Class
# 1159    1160  CA-2017-147039 2017-06-29 2017-07-04  Standard Class
# 7469    7470  CA-2014-138100 2014-09-15 2014-09-20  Standard Class
# ...      ...             ...        ...        ...             ...
# 8341    8342  CA-2017-141481 2017-06-11 2017-06-14     First Class
# 3040    3041  US-2016-147991 2016-05-05 2016-05-09  Standard Class
# 3815    3816  CA-2016-152471 2016-07-08 2016-07-08        Same Day
# 5898    5899  CA-2016-167682 2016-04-03 2016-04-09  Standard Class
# 18        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class
#
#      Customer ID       Customer Name   Segment        Country           City  \
# 2229    AA-10315          Alex Avila  Consumer  United States  San Francisco
# ...

# %%
# to fetch out random rows :

a.sample(frac=.70)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 8030    8031  CA-2016-158806 2016-01-07 2016-01-11  Standard Class
# 3948    3949  CA-2016-119963 2016-11-18 2016-11-22  Standard Class
# 7829    7830  CA-2015-137302 2015-04-26 2015-05-01  Standard Class
# 5449    5450  US-2014-119081 2014-09-12 2014-09-19  Standard Class
# 5486    5487  CA-2015-156608 2015-10-24 2015-10-29  Standard Class
# ...      ...             ...        ...        ...             ...
# 1739    1740  CA-2015-130204 2015-09-03 2015-09-09  Standard Class
# 5981    5982  CA-2014-117765 2014-09-07 2014-09-13  Standard Class
# 4149    4150  CA-2017-106068 2017-10-23 2017-10-28  Standard Class
# 2328    2329  CA-2017-138422 2017-09-23 2017-09-26     First Class
# 2285    2286  CA-2016-112676 2016-05-05 2016-05-08     First Class
#
#      Customer ID  Customer Name      Segment        Country           City  \
# 8030    NM-18520   Neoma Murray     Consumer  United States       Amarillo
# ...

# %%
a.tail(200).sort_values("Customer ID")     # to extract particular no of rows and sorting on the basis of any feature
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9821    9822  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# 9820    9821  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# 9819    9820  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# 9818    9819  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# 9817    9818  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 9914    9915  CA-2017-160927 2017-01-29 2017-01-31    Second Class
# 9917    9918  CA-2017-160927 2017-01-29 2017-01-31    Second Class
# 9889    9890  CA-2017-166499 2017-03-19 2017-03-20     First Class
# 9834    9835  CA-2016-126627 2016-10-10 2016-10-12     First Class
# 9835    9836  CA-2016-126627 2016-10-10 2016-10-12     First Class
#
#      Customer ID    Customer Name    Segment        Country              City  \
# 9821    AG-10495  Andrew Gjertsen  Corporate  United States  Saint Petersburg
# ...

# %%
a["Order ID"].unique()
# Out:
# array(['CA-2016-152156', 'CA-2016-138688', 'US-2015-108966', ...,
#        'CA-2014-110422', 'CA-2017-121258', 'CA-2017-119914'], dtype=object)

# %%
len(a["Order ID"].unique())
# Out:
# 5009

# %%
# no of order IDs that are unique:

a["Order ID"].unique().shape
# Out:
# (5009,)

# %%
# frequency of each Order IDs:


c=[]       
for i in a["Order ID"].unique():
    for j in a["Order ID"]:
        if i==j:
            c.append(j)
    print(i,c.count(i))
# Out:
# CA-2016-152156 2
# CA-2016-138688 1
# US-2015-108966 2
# CA-2014-115812 7
# CA-2017-114412 1
# CA-2016-161389 1
# US-2015-118983 2
# CA-2014-105893 1
# CA-2014-167164 1
# CA-2014-143336 3
# CA-2016-137330 2
# US-2017-156909 1
# CA-2015-106320 1
# CA-2016-121755 2
# US-2015-150630 7
# CA-2017-107727 1
# CA-2016-117590 2
# CA-2015-117415 4
# CA-2017-120999 1
# CA-2016-101343 1
# CA-2017-139619 1
# CA-2016-118255 2
# CA-2014-146703 1
# CA-2016-169194 2
# CA-2015-115742 4
# CA-2016-105816 2
# CA-2016-111682 7
# CA-2015-135545 4
# US-2015-164175 1
# CA-2014-106376 2
# CA-2016-119823 1
# CA-2016-106075 1
# CA-2017-114440 1
# US-2015-134026 3
# US-2017-118038 3
# US-2014-147606 1
# CA-2016-127208 2
# CA-2014-139451 2
# CA-2015-149734 1
# US-2017-119662 1
# CA-2017-140088 1
# CA-2017-155558 2
# CA-2016-159695 1
# CA-2016-109806 3
# CA-2015-149587 3
# US-2017-109484 1
# CA-2017-161018 1
# CA-2017-157833 1
# CA-2016-149223 1
# CA-2016-158568 3
# CA-2016-129903 1
# US-2015-156867 3
# ...

# %%
# unique IDs in customer IDs:


a["Customer ID"].unique()
# Out:
# array(['CG-12520', 'DV-13045', 'SO-20335', 'BH-11710', 'AA-10480',
#        'IM-15070', 'HP-14815', 'PK-19075', 'AG-10270', 'ZD-21925',
#        'KB-16585', 'SF-20065', 'EB-13870', 'EH-13945', 'TB-21520',
#        'MA-17560', 'GH-14485', 'SN-20710', 'LC-16930', 'RA-19885',
#        'ES-14080', 'ON-18715', 'PO-18865', 'LH-16900', 'DP-13000',
#        'JM-15265', 'TB-21055', 'KM-16720', 'PS-18970', 'BS-11590',
#        'KD-16270', 'HM-14980', 'JE-15745', 'KB-16600', 'SC-20770',
#        'DN-13690', 'JC-16105', 'CS-12400', 'PG-18895', 'GM-14455',
#        'JS-15685', 'KB-16315', 'RB-19705', 'PN-18775', 'KD-16345',
#        'ER-13855', 'RB-19465', 'GZ-14470', 'LC-16870', 'JM-15250',
#        'PA-19060', 'CV-12805', 'CL-12565', 'RC-19960', 'DK-13090',
#        'GG-14650', 'SC-20725', 'AD-10180', 'PF-19165', 'TS-21610',
#        'LS-16975', 'DW-13585', 'LC-16885', 'JD-15895', 'SH-19975',
#        'SG-20080', 'HA-14920', 'MG-17680', 'JE-16165', 'TW-21025',
# ...

# %%
a["Customer ID"].unique().shape  # total no of customer IDs
# Out:
# (793,)

# %%
# to fetch out data of by Customer ID:


def customerid(q):
    for i in a["Customer ID"]:
        if q==i:
            return (a[a["Customer ID"]==q])

# %%
customerid("MA-17560")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 34        35  CA-2017-107727 2017-10-19 2017-10-23    Second Class
# 3252    3253  CA-2017-110373 2017-10-27 2017-10-30    Second Class
# 3253    3254  CA-2017-110373 2017-10-27 2017-10-30    Second Class
# 4199    4200  CA-2015-143105 2015-12-10 2015-12-10        Same Day
# 4200    4201  CA-2015-143105 2015-12-10 2015-12-10        Same Day
# 4201    4202  CA-2015-143105 2015-12-10 2015-12-10        Same Day
# 4202    4203  CA-2015-143105 2015-12-10 2015-12-10        Same Day
# 4234    4235  CA-2014-168823 2014-09-21 2014-09-24     First Class
# 4235    4236  CA-2014-168823 2014-09-21 2014-09-24     First Class
# 5068    5069  CA-2014-124478 2014-08-08 2014-08-12  Standard Class
# 5069    5070  CA-2014-124478 2014-08-08 2014-08-12  Standard Class
# 5070    5071  CA-2014-124478 2014-08-08 2014-08-12  Standard Class
# 5071    5072  CA-2014-124478 2014-08-08 2014-08-12  Standard Class
# ...

# %%
customerid("MA-17560").shape[0]  # total no of entries of a particular Cutomer ID
# Out:
# 34

# %%
# descriptive statistics of a particular Customet ID:
 
customerid("MA-17560").drop(["Row ID","Postal Code"], axis=1).describe()
# Out:
#             Sales   Quantity   Discount      Profit
# count   34.000000  34.000000  34.000000   34.000000
# mean   126.445912   3.441176   0.094118   36.477253
# std    193.702573   2.062525   0.159433   63.278693
# min      1.980000   1.000000   0.000000   -3.820800
# 25%     15.862500   2.000000   0.000000    3.605550
# 50%     38.655000   3.000000   0.000000   13.763400
# 75%    164.376250   4.000000   0.200000   36.044050
# max    799.984000   9.000000   0.600000  274.995000

# %%
customerid("MA-17560").sort_values("Category")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9125    9126  CA-2016-128916 2016-08-18 2016-08-20    Second Class
# 9124    9125  CA-2016-128916 2016-08-18 2016-08-20    Second Class
# 7674    7675  CA-2015-130974 2015-11-27 2015-11-29    Second Class
# 7672    7673  CA-2015-130974 2015-11-27 2015-11-29    Second Class
# 7671    7672  CA-2015-130974 2015-11-27 2015-11-29    Second Class
# 5071    5072  CA-2014-124478 2014-08-08 2014-08-12  Standard Class
# 34        35  CA-2017-107727 2017-10-19 2017-10-23    Second Class
# 9354    9355  CA-2015-110324 2015-12-01 2015-12-05  Standard Class
# 7989    7990  US-2016-117793 2016-08-23 2016-08-29  Standard Class
# 7988    7989  US-2016-117793 2016-08-23 2016-08-29  Standard Class
# 7987    7988  US-2016-117793 2016-08-23 2016-08-29  Standard Class
# 7673    7674  CA-2015-130974 2015-11-27 2015-11-29    Second Class
# 7669    7670  CA-2015-130974 2015-11-27 2015-11-29    Second Class
# ...

# %%
len(a["Customer ID"].unique()) # total no of unique Customer IDs
# Out:
# 793

# %%
# frequency of each Customer ID:


C=[]       
for i in a["Customer ID"].unique():
    for j in a["Customer ID"]:
        if i==j:
            C.append(j)
    print(i,C.count(i))
# Out:
# CG-12520 5
# DV-13045 9
# SO-20335 15
# BH-11710 24
# AA-10480 12
# IM-15070 21
# HP-14815 10
# PK-19075 25
# AG-10270 14
# ZD-21925 9
# KB-16585 23
# SF-20065 9
# EB-13870 11
# EH-13945 17
# TB-21520 20
# MA-17560 34
# GH-14485 3
# SN-20710 19
# LC-16930 14
# RA-19885 15
# ES-14080 20
# ON-18715 15
# PO-18865 13
# LH-16900 15
# DP-13000 17
# JM-15265 13
# TB-21055 18
# KM-16720 28
# PS-18970 13
# BS-11590 10
# KD-16270 16
# HM-14980 7
# JE-15745 23
# KB-16600 9
# SC-20770 21
# DN-13690 11
# JC-16105 9
# CS-12400 14
# PG-18895 17
# GM-14455 12
# JS-15685 11
# KB-16315 22
# RB-19705 7
# PN-18775 13
# KD-16345 10
# ER-13855 5
# RB-19465 23
# GZ-14470 14
# LC-16870 30
# JM-15250 19
# PA-19060 7
# CV-12805 19
# CL-12565 28
# RC-19960 11
# DK-13090 13
# GG-14650 24
# SC-20725 26
# AD-10180 12
# PF-19165 10
# TS-21610 11
# LS-16975 22
# DW-13585 10
# LC-16885 23
# JD-15895 32
# SH-19975 29
# SG-20080 11
# HA-14920 18
# MG-17680 10
# JE-16165 7
# TW-21025 12
# SP-20650 15
# NK-18490 11
# ...

# %%
# Total no customers present in the data

a["Customer Name"].unique().shape
# Out:
# (793,)

# %%
# by this we can fetchout the data of any customer by using his/her name:


def customername(q):
    for i in a["Customer Name"]:
        if q==i:
            return (a[a["Customer Name"]==q])

# %%
customername("Zuschuss Donatelli")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 18        19  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 19        20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 20        21  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# 3040    3041  US-2016-147991 2016-05-05 2016-05-09  Standard Class
# 3814    3815  CA-2016-152471 2016-07-08 2016-07-08        Same Day
# 3815    3816  CA-2016-152471 2016-07-08 2016-07-08        Same Day
# 5897    5898  CA-2016-167682 2016-04-03 2016-04-09  Standard Class
# 5898    5899  CA-2016-167682 2016-04-03 2016-04-09  Standard Class
# 8341    8342  CA-2017-141481 2017-06-11 2017-06-14     First Class
#
#      Customer ID       Customer Name   Segment        Country           City  \
# 18      ZD-21925  Zuschuss Donatelli  Consumer  United States  San Francisco
# 19      ZD-21925  Zuschuss Donatelli  Consumer  United States  San Francisco
# ...

# %%
# droping of irreleavant coloumns :

customername("Zuschuss Donatelli").drop(["Order Date","Customer Name", "Ship Date", "Postal Code", "Segment", "Region", "Country"], axis=1)
# Out:
#       Row ID        Order ID       Ship Mode Customer ID           City  \
# 18        19  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 19        20  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 20        21  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 3040    3041  US-2016-147991  Standard Class    ZD-21925    Chattanooga
# 3814    3815  CA-2016-152471        Same Day    ZD-21925   Jacksonville
# 3815    3816  CA-2016-152471        Same Day    ZD-21925   Jacksonville
# 5897    5898  CA-2016-167682  Standard Class    ZD-21925       Richmond
# 5898    5899  CA-2016-167682  Standard Class    ZD-21925       Richmond
# 8341    8342  CA-2017-141481     First Class    ZD-21925    Los Angeles
#
#            State       Product ID         Category Sub-Category  \
# 18    California  OFF-AR-10003056  Office Supplies          Art
# 19    California  TEC-PH-10001949       Technology       Phones
# ...

# %%
# droping and sorting on the basis of sales:

customername("Zuschuss Donatelli").drop(["Order Date","Customer Name", "Ship Date", "Postal Code", "Segment", "Region", "Country"], axis=1).sort_values("Sales")
# Out:
#       Row ID        Order ID       Ship Mode Customer ID           City  \
# 18        19  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 3815    3816  CA-2016-152471        Same Day    ZD-21925   Jacksonville
# 3040    3041  US-2016-147991  Standard Class    ZD-21925    Chattanooga
# 20        21  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 8341    8342  CA-2017-141481     First Class    ZD-21925    Los Angeles
# 5897    5898  CA-2016-167682  Standard Class    ZD-21925       Richmond
# 19        20  CA-2014-143336    Second Class    ZD-21925  San Francisco
# 5898    5899  CA-2016-167682  Standard Class    ZD-21925       Richmond
# 3814    3815  CA-2016-152471        Same Day    ZD-21925   Jacksonville
#
#            State       Product ID         Category Sub-Category  \
# 18    California  OFF-AR-10003056  Office Supplies          Art
# 3815     Florida  OFF-PA-10004965  Office Supplies        Paper
# ...

# %%
customername("Zuschuss Donatelli").shape[0]
# Out:
# 9

# %%
customername("Zuschuss Donatelli").drop(["Row ID", "Postal Code"], axis=1).describe()
# Out:
#             Sales  Quantity  Discount      Profit
# count    9.000000  9.000000  9.000000    9.000000
# mean   165.993778  3.555556  0.111111   27.681189
# std    263.162267  1.130388  0.105409   39.434192
# min      8.560000  2.000000  0.000000    2.482400
# 25%     16.720000  3.000000  0.000000    4.995000
# 50%     61.440000  4.000000  0.200000   16.011000
# 75%    213.480000  4.000000  0.200000   22.047200
# max    823.960000  5.000000  0.200000  124.780800

# %%
customername("Zuschuss Donatelli")["City"]
# Out:
# 18      San Francisco
# 19      San Francisco
# 20      San Francisco
# 3040      Chattanooga
# 3814     Jacksonville
# 3815     Jacksonville
# 5897         Richmond
# 5898         Richmond
# 8341      Los Angeles
# Name: City, dtype: object

# %%
a.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
# ANALYSIS ON THE BASIS OF SEGMENT FEATURE#

# unique values under segment feature

a["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
def segment(h):
    for i in a["Segment"]:
        if h==i:
            return (a[a["Segment"]==h])

# %%
# List of customers falls under "consumer" segment:

segment("Consumer")
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# 0       CG-12520       Claire Gute  Consumer  United States        Henderson
# ...

# %%
# total no entries falls under "consumer" segment

segment("Consumer").shape[0]
# Out:
# 5191

# %%
# name of customers who are under "Consumer Segment"

segment("Consumer")["Customer Name"].unique()
# Out:
# array(['Claire Gute', "Sean O'Donnell", 'Brosina Hoffman', 'Andrew Allen',
#        'Irene Maddox', 'Pete Kriz', 'Alejandro Grove',
#        'Zuschuss Donatelli', 'Sandra Flanagan', 'Emily Burns',
#        'Eric Hoffmann', 'Tracy Blumstein', "Patrick O'Donnell",
#        'Lena Hernandez', 'Darren Powers', 'Ted Butterfield',
#        'Kunst Miller', 'Karen Daniels', 'Henry MacAllister', 'Joel Eaton',
#        'Duane Noonan', 'Paul Gonzalez', 'Karl Braun', 'Katherine Ducich',
#        'Gary Zandusky', 'Lena Cacioppo', 'Janet Martin', 'Clay Ludtke',
#        'Ryan Crowe', 'Dave Kipp', 'Steven Cartwright', 'Philip Fox',
#        'Troy Staebel', 'Lena Creighton', 'Sandra Glassco',
#        'Helen Andreada', 'Dave Brooks', 'Nora Paige', 'Ted Trevino',
#        'Eric Murdock', 'Ruben Dartt', 'Max Jones', 'Becky Martin',
#        'Chad Sievert', 'Shirley Jackson', 'Sally Knutson',
#        'Cassandra Brandow', 'Maria Bertelson', 'Bruce Stewart',
# ...

# %%
# total no of customer under the "Consumer Segment"

segment("Consumer")["Customer Name"].unique().shape
# Out:
# (409,)

# %%
segment("Home Office").shape  # total entries of "Home Office" under "Segment" feature


segment("Home Office")["Customer Name"].unique() # names of consumers under the "Home Office" Segment

segment("Home Office")["Customer Name"].unique().shape  # total no customer under the "Home Office" Segment
# Out:
# (148,)

# %%
segment("Corporate")["Customer Name"].unique().shape
# Out:
# (236,)

# %%
# Analysis:

# Total No of customers present under the 3 Segments i.e. "Consumer", "Corporate" and "Home Office" is 793

# so there is no customer who comes under the two segments.

# %%
segment("Home Office")["Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
segment("Home Office")["Sub-Category"].unique()
# Out:
# array(['Appliances', 'Binders', 'Paper', 'Envelopes', 'Bookcases',
#        'Chairs', 'Phones', 'Storage', 'Furnishings', 'Accessories', 'Art',
#        'Tables', 'Fasteners', 'Labels', 'Machines', 'Supplies', 'Copiers'],
#       dtype=object)
